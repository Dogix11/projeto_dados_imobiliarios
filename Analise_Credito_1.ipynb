# %%
import pandas as pd
import matplotlib as plt
import re
import numpy as np

# %%
df = pd.read_csv("./df_organizado.csv", sep= ',')

# Filtrando apenas 'credito'
df_credito = df[df['tipo_transacao'] == 'credito']

df_credito.to_csv('credito_movimentacoes.csv', index=False)

# %%
df = pd.read_csv("./credito_movimentacoes.csv", sep= ',')

df['tipo_credito'] = df.apply(lambda row: row['info'].split('_')[0] if row['tipo_transacao'] == 'credito' else None, axis=1)

df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))

df.columns = ['data', 'info', 'valor', 'tipo_transacao','estado','tipo_credito']

df.head(10)
# Out:
#          data                            info         valor tipo_transacao  \
# 0  2014-04-30                 indexador_pf_tr  1.608026e+10        credito
# 1  2014-04-30        carteira_credito_pf_fgts  2.763158e+09        credito
# 2  2014-04-30                ltv_pf_comercial  5.537000e+01        credito
# 3  2014-04-30            inadimplencia_pf_sfh  3.280000e+00        credito
# 4  2014-04-30  risco_operacao_pf_comercial_aa  9.470000e+00        credito
# 5  2014-04-30       risco_operacao_pf_livre_c  3.330000e+00        credito
# 6  2014-04-30                 indexador_pf_tr  4.932495e+08        credito
# 7  2014-04-30                ltv_pf_comercial  6.234000e+01        credito
# 8  2014-04-30  risco_operacao_pj_livre_d_mais  2.330000e+00        credito
# 9  2014-04-30              contratado_pf_fgts  2.244158e+08        credito
#
#   estado tipo_credito
# 0     sc      estoque
# 1     pe      estoque
# 2     pr  contratacao
# 3     ac      estoque
# 4     rs      estoque
# 5     sc      estoque
# 6     ac      estoque
# 7     mg  contratacao
# 8     ms      estoque
# 9     pr  contratacao

# %%
df['coluna_9'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))
df['coluna_10'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))
df['coluna_11'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))
df['coluna_12'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))
df['coluna_13'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))
df['coluna_14'] = df['info'].apply(lambda x: x.split('_')[0])
df['info'] = df['info'].apply(lambda x: '_'.join(x.split('_')[1:]))

df.columns = ['data', 'info', 'valor', 'tipo_transacao','estado','tipo_credito', 'coluna_9', 'coluna_10', 'coluna_11', 'coluna_12', 'coluna_13', 'coluna_14']

df = df.drop(columns=['info'])
#Juntando colunas
df['coluna_13'] = df['coluna_13'].astype(str) + ' ' + df['coluna_14'].astype(str)
# Deletando a ultima coluna
df = df.drop(columns=['coluna_14'])

df.head(10)
# Out:
#          data         valor tipo_transacao estado tipo_credito       coluna_9  \
# 0  2014-04-30  1.608026e+10        credito     sc      estoque      indexador
# 1  2014-04-30  2.763158e+09        credito     pe      estoque       carteira
# 2  2014-04-30  5.537000e+01        credito     pr  contratacao            ltv
# 3  2014-04-30  3.280000e+00        credito     ac      estoque  inadimplencia
# 4  2014-04-30  9.470000e+00        credito     rs      estoque          risco
# 5  2014-04-30  3.330000e+00        credito     sc      estoque          risco
# 6  2014-04-30  4.932495e+08        credito     ac      estoque      indexador
# 7  2014-04-30  6.234000e+01        credito     mg  contratacao            ltv
# 8  2014-04-30  2.330000e+00        credito     ms      estoque          risco
# 9  2014-04-30  2.244158e+08        credito     pr  contratacao     contratado
#
#   coluna_10  coluna_11  coluna_12 coluna_13
# 0        pf         tr
# 1   credito         pf       fgts
# 2        pf  comercial
# 3        pf        sfh
# 4  operacao         pf  comercial       aa
# 5  operacao         pf      livre        c
# 6        pf         tr
# 7        pf  comercial
# 8  operacao         pj      livre    d mais
# 9        pf       fgts

# %%
# Criando a coluna clientes
df['tipo_cliente'] = None

# Atualizando a coluna clientes com o tipo de cliente.
df.loc[df['coluna_10'].isin(['pj', 'pf']), 'tipo_cliente'] = df['coluna_10']
df.loc[df['coluna_11'].isin(['pj', 'pf']), 'tipo_cliente'] = df['coluna_11']

df.head(10)
# Out:
#          data         valor tipo_transacao estado tipo_credito       coluna_9  \
# 0  2014-04-30  1.608026e+10        credito     sc      estoque      indexador
# 1  2014-04-30  2.763158e+09        credito     pe      estoque       carteira
# 2  2014-04-30  5.537000e+01        credito     pr  contratacao            ltv
# 3  2014-04-30  3.280000e+00        credito     ac      estoque  inadimplencia
# 4  2014-04-30  9.470000e+00        credito     rs      estoque          risco
# 5  2014-04-30  3.330000e+00        credito     sc      estoque          risco
# 6  2014-04-30  4.932495e+08        credito     ac      estoque      indexador
# 7  2014-04-30  6.234000e+01        credito     mg  contratacao            ltv
# 8  2014-04-30  2.330000e+00        credito     ms      estoque          risco
# 9  2014-04-30  2.244158e+08        credito     pr  contratacao     contratado
#
#   coluna_10  coluna_11  coluna_12 coluna_13 tipo_cliente
# 0        pf         tr                                pf
# 1   credito         pf       fgts                     pf
# 2        pf  comercial                                pf
# 3        pf        sfh                                pf
# 4  operacao         pf  comercial       aa            pf
# 5  operacao         pf      livre        c            pf
# 6        pf         tr                                pf
# 7        pf  comercial                                pf
# 8  operacao         pj      livre    d mais           pj
# 9        pf       fgts                                pf

# %%
columns_to_replace = ['coluna_10', 'coluna_11']

for column in columns_to_replace:
    df[column] = df[column].replace({'pj': '', 'pf': ''})

df.head(10)
# Out:
#          data         valor tipo_transacao estado tipo_credito       coluna_9  \
# 0  2014-04-30  1.608026e+10        credito     sc      estoque      indexador
# 1  2014-04-30  2.763158e+09        credito     pe      estoque       carteira
# 2  2014-04-30  5.537000e+01        credito     pr  contratacao            ltv
# 3  2014-04-30  3.280000e+00        credito     ac      estoque  inadimplencia
# 4  2014-04-30  9.470000e+00        credito     rs      estoque          risco
# 5  2014-04-30  3.330000e+00        credito     sc      estoque          risco
# 6  2014-04-30  4.932495e+08        credito     ac      estoque      indexador
# 7  2014-04-30  6.234000e+01        credito     mg  contratacao            ltv
# 8  2014-04-30  2.330000e+00        credito     ms      estoque          risco
# 9  2014-04-30  2.244158e+08        credito     pr  contratacao     contratado
#
#   coluna_10  coluna_11  coluna_12 coluna_13 tipo_cliente
# 0                   tr                                pf
# 1   credito                  fgts                     pf
# 2            comercial                                pf
# 3                  sfh                                pf
# 4  operacao             comercial       aa            pf
# 5  operacao                 livre        c            pf
# 6                   tr                                pf
# 7            comercial                                pf
# 8  operacao                 livre    d mais           pj
# 9                 fgts                                pf
